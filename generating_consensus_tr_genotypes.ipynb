# %% [markdown]
# This notebook describes steps for installing the necessary software and genotyping TRs using using HipSTR, GangSTR, ExpansionHunter, and adVNTR. EnsembleTR is used to generate consensus TR genotypes from genotypes obtained from TR genotypers

# %% [markdown]
# # Obtain data

# %%
# download toy dataset, about 2.09 GB
wget https://figshare.com/ndownloader/files/45851871

# %%
# extract files from the archive 
tar -xvf example_data.tar.gz

# %%
# create output directory
mkdir -p output/{hipstr_output,advntr_output/advntr_dir,gangstr_output,eh_output,ensembletr_output}

tree output
# Out:
# output
# ├── advntr_output
# │   └── advntr_dir
# ├── eh_output
# ├── ensembletr_output
# ├── gangstr_output
# └── hipstr_output
#
# 6 directories, 0 files

# %% [markdown]
# # Installing tools

# %% [markdown]
# ## bcftools and tabix

# %%
# steps to install bcftools are described here, https://samtools.github.io/bcftools/howtos/install.html

git clone --recurse-submodules https://github.com/samtools/htslib.git
git clone https://github.com/samtools/bcftools.git
cd bcftools
make

# %% [markdown]
# ## HipSTR

# %%
# HipSTR

# install these dependencies if you do not have them by uncommenting the line below

# apt install g++ make zlib1g-dev libhts-dev libbz2-dev liblzma-dev

git clone https://github.com/gymrek-lab/HipSTR.git
cd HipSTR
make version && make

# %%
./HipSTR --help
cd ..

# %% [markdown]
# ## ExpansionHunter

# %%
# ExpansionHunter
version=v5.0.0-linux_x86_64

wget https://github.com/Illumina/ExpansionHunter/releases/download/v5.0.0/ExpansionHunter-v5.0.0-linux_x86_64.tar.gz

tar -xzvf ExpansionHunter-v5.0.0-linux_x86_64.tar.gz

# %%
# The ExpansionHunter executable can be found in 
ExpansionHunter-v5.0.0-linux_x86_64/bin/ExpansionHunter --help

# %% [markdown]
# ## GangSTR

# %%
 # GangSTR

mamba create -y --name gangstr
mamba activate gangstr
mamba config --add channels conda-forge
mamba config --add channels bioconda
mamba install -y -c conda-forge -c bioconda gangstr

# %%
# this step maybe optional
# only run if you get this error
# GangSTR: error while loading shared libraries: libgsl.so.25: cannot open shared object file: No such file or directory
mamba install -y conda-forge::gsl

# %%
GangSTR --help

mamba deactivate

# %% [markdown]
# ## adVNTR

# %%
# advntr
mamba create -y --name advntr
mamba activate advntr
mamba config --add channels conda-forge
mamba config --add channels bioconda
mamba install -y -c conda-forge -c bioconda advntr

# %%
# this step is optional
# run if the step below returns
# WARNING (theano.configdefaults): install mkl with `conda install mkl-service`: No module named 'mkl'

mamba install -y mkl-service

# %%
advntr 
mamba deactivate

# %% [markdown]
# ## EnsembleTR

# %%
# ensembleTR
git clone https://github.com/gymrek-lab/EnsembleTR.git
cd EnsembleTR
python3 setup.py install --user

# %%
EnsembleTR --version
cd ..

# %% [markdown]
# ## TRtools

# %%
git clone https://github.com/gymrek-lab/TRTools.git
cd TRTools/
python3 -m pip install --upgrade pip
python3 -m pip install -e .
cd ..

# %% [markdown]
# ## vcftools

# %%
git clone https://github.com/vcftools/vcftools.git
cd vcftools
./autogen.sh
./configure
make
sudo make install

cd ..

# %%
# check software
./check_software.sh statSTR associaTR compareSTR dumpSTR mergeSTR prancSTR qcSTR simTR vcftools | grep -i 'not installed'
# Out:
# : 1

# %% [markdown]
# # Genotyping STRs and preprocessing VCF files

# %% [markdown]
# ## HipSTR

# %%
# HipSTR

populations=("africa" "europe" "east_asia" "south_asia" "america")
reference_genome="references/reference_chroms.fa"

for population in "${populations[@]}"; do
    
    bam_files=$(cat str_resources/"${population}".txt | tr "\n" ",")

    HipSTR/HipSTR --bams $bam_files \
        --fasta $reference_genome \
        --regions str_resources/hipstr_reference.bed \
        --str-vcf output/hipstr_output/"${population}"_hipstr.vcf.gz \
        --log output/hipstr_output/"${population}"_strs.log \
        --viz-out output/hipstr_output/"${population}"_strs.viz.gz \
        --output-gls --output-pls --def-stutter-model
        
    zcat output/hipstr_output/"${population}"_hipstr.vcf.gz | vcf-sort | bgzip -c > output/hipstr_output/"${population}"_hipstr_sorted.vcf.gz
    tabix -p vcf output/hipstr_output/"${population}"_hipstr_sorted.vcf.gz
    
done
# Out:
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n

# %% [markdown]
# ### Understanding HipSTR output

# %%
vcftools --gzvcf output/hipstr_output/africa_hipstr.vcf.gz --snp TIMM10 --indv NA20357 --recode --recode-INFO-all --stdout | tail -n 2 | datamash transpose
# Out:
# #CHROM	chr11
# POS	57528484
# ID	TIMM10
# REF	TATATATATATATATATATATATATATATATATA
# ALT	TATATATATATATATATATATATA,TATATATATATATATATATATATATA,TATATATATATATATATATATATATACA,TATATATATATATATATATATATATATA,TATATATATATATATATATATATATATATA,TATATATATATATATATATATATATATATATA,TATATATATATATATATATATATATATATATATATATA
# QUAL	.
# FILTER	.
# INFO	INFRAME_PGEOM=0.95;INFRAME_UP=0.05;INFRAME_DOWN=0.05;OUTFRAME_PGEOM=0.95;OUTFRAME_UP=0.01;OUTFRAME_DOWN=0.01;START=57528484;END=57528517;PERIOD=2;NSKIP=0;NFILT=0;BPDIFFS=-10,-8,-6,-6,-4,-2,4;DP=992;DSNP=0;DSTUTTER=22;DFLANKINDEL=13;AN=100;REFAC=5;AC=11,58,1,12,7,2,4
# FORMAT	GT:GB:Q:PQ:DP:DSNP:DSTUTTER:DFLANKINDEL:PDP:PSNP:GLDIFF:AB:DAB:FS:ALLREADS:MALLREADS:GL:PL
# NA20357	2|2:-8|-8:1.00:1.00:18:0:0:0:9.00|9.00:0|0:3.38:0:.:0:-8|12:-8|11:-109.14,-66.28,-62.67,-49.88,-49.66,-46.27,-73.62,-65.65,-51.31,-80.33,-65.93,-62.49,-49.64,-65.40,-62.32,-81.53,-66.01,-49.86,-72.64,-65.68,-77.93,-96.90,-66.26,-49.88,-73.57,-65.92,-81.29,-93.54,-112.73,-66.27,-49.87,-73.62,-65.93,-81.54,-97.15,-139.41:628,200,164,36,33,0,273,193,50,340,196,162,33,191,160,352,197,35,263,194,316,506,199,36,272,196,350,472,664,200,36,273,196,352,508,931

# %% [markdown]
# ### Visualising HipSTR alignments

# %%
# index the file with visualisation
tabix -p vcf output/hipstr_output/africa_strs.viz.gz

# %%
# visualising alignments at chr17:51831668 for Africa super population
## africa
HipSTR/VizAlnPdf output/hipstr_output/africa_strs.viz.gz chr17 51831668 NA20357 viz_NA20357 3

# %%
convert -density 300 -quality 90 viz_NA20357.pdf -resize 25% NA20357.png
# display HG002330.png

# %% [markdown]
# ![alignment](./NA20357.png)

# %% [markdown]
# ## ExpansionHunter

# %%
reference_genome="references/reference_chroms.fa"
output_dir=output/eh_output
male_list=str_resources/bams_male.txt
female_list=str_resources/bams_female.txt
eh_reference_strs=str_resources/eh_reference.json

# males
for sample_bam in $(cat $male_list); do
        
    sample_id=$(basename $sample_bam | cut -f1 -d".")        

    ExpansionHunter-v5.0.0-linux_x86_64/bin/ExpansionHunter \
            --threads 32 \
            --reads $sample_bam \
            --reference $reference_genome \
            --variant-catalog $eh_reference_strs \
            --output-prefix $output_dir/$sample_id \
            --sex male \
            --log-level trace

    # eh vcf files do not have contigs listed in the header
    cat output/eh_output/"${sample_id}".vcf | vcf-sort | bgzip -c > output/eh_output/"${sample_id}"_sorted.vcf.gz
    tabix -p vcf output/eh_output/"${sample_id}"_sorted.vcf.gz

done


# females
for sample_bam in $(cat $female_list); do
    
    sample_id=$(basename $sample_bam | cut -f1 -d".")        

    ExpansionHunter-v5.0.0-linux_x86_64/bin/ExpansionHunter \
            --threads 32 \
            --reads $sample_bam \
            --reference $reference_genome \
            --variant-catalog $eh_reference_strs \
            --output-prefix $output_dir/$sample_id \
            --sex female \
            --log-level trace
                
    # eh vcf files do not have contigs listed in the header
    cat output/eh_output/"${sample_id}".vcf | vcf-sort | bgzip -c > output/eh_output/"${sample_id}"_sorted.vcf.gz
    tabix -p vcf output/eh_output/"${sample_id}"_sorted.vcf.gz
    
done
# Out:
# 2024-04-22T19:43:16,[Starting ExpansionHunter v5.0.0]
# 2024-04-22T19:43:16,[Analyzing sample HG00108]
# 2024-04-22T19:43:16,[Initializing reference references/reference_chroms.fa]
# 2024-04-22T19:43:16,[Loading variant catalog from disk str_resources/eh_reference.json]
# 2024-04-22T19:43:16,[Running sample analysis in seeking mode]
# 2024-04-22T19:43:16,[Analyzing HTT]
# 2024-04-22T19:43:16,[Analyzing ESR2]
# 2024-04-22T19:43:16,[Collected 475 reads from (3):3073877-3075966]
# 2024-04-22T19:43:16,[Recovered 0 reads]
# 2024-04-22T19:43:16,[Analyzing CA10]
# 2024-04-22T19:43:16,[Analyzing NEXN]
# 2024-04-22T19:43:16,[Collected 183 reads from (0):77886913-77889010]
# 2024-04-22T19:43:16,[Recovered 0 reads]
# 2024-04-22T19:43:16,[Analyzing TIMM10]
# 2024-04-22T19:43:16,[Collected 282 reads from (10):57527484-57529517]
# 2024-04-22T19:43:16,[Could not recover the mate of A00217:72:HFKHYDSXX:1:2512:16387:18693/1]
# 2024-04-22T19:43:16,[Recovered 0 reads]
# 2024-04-22T19:43:16,[Collected 590 reads from (13):64252561-64254619]
# 2024-04-22T19:43:16,[Could not recover the mate of A00217:73:HFKLJDSXX:1:2425:4200:30780/1]
# 2024-04-22T19:43:16,[Could not recover the mate of A00217:73:HFKLJDSXX:2:2369:6017:25066/1]
# 2024-04-22T19:43:16,[Could not recover the mate of A00217:71:HFHVLDSXX:2:2256:14127:16376/1]
# 2024-04-22T19:43:16,[Could not recover the mate of A00217:73:HFKLJDSXX:1:2616:26738:29074/1]
# 2024-04-22T19:43:16,[Could not recover the mate of A00217:72:HFKHYDSXX:4:2432:17535:7498/1]
# 2024-04-22T19:43:16,[Could not recover the mate of A00217:73:HFKLJDSXX:4:2273:15194:24862/1]
# 2024-04-22T19:43:16,[Could not recover the mate of A00217:72:HFKHYDSXX:4:2432:17499:7748/1]
# 2024-04-22T19:43:16,[Could not recover the mate of A00217:73:HFKLJDSXX:4:2327:27778:15374/1]
# 2024-04-22T19:43:16,[Could not recover the mate of A00217
    grep -f str_resources/"${population}"_ids.csv | tr "\n" "," | sed 's/,$//')
    
    mergeSTR \
        --vcfs $sample_vcfs \
        --vcftype 'eh' \
        --out output/eh_output/"${population}"_eh
        
    cat output/eh_output/"${population}"_eh.vcf | vcf-sort | bgzip -c output/eh_output/"${population}"_eh.vcf.gz
    tabix -p vcf output/eh_output/"${population}"_eh.vcf.gz
    
    # filtering with dumpSTR
#     dumpSTR --vcf output/eh_output/"${population}"_eh.vcf \
#         --out output/eh_output/"${population}"_eh_filt \
#         --vcftype 'eh' 
        
#     bgzip output/eh_output/"${population}"_eh_filt.vcf
#     tabix -p vcf output/eh_output/"${population}"_eh_filt.vcf.gz

done

# %% [markdown]
# ## GangSTR

# %%
mamba activate gangstr

reference_genome="references/reference_chroms.fa"
output_dir=output/gangstr_output
male_list=str_resources/bams_male.txt
female_list=str_resources/bams_female.txt
gangstr_reference_strs=str_resources/gangstr_reference.bed

# male samples
for sample_bam in $(cat $male_list); do

    sample_id=$(basename $sample_bam | cut -f1 -d".")

    GangSTR --bam $sample_bam \
            --bam-samps $sample_id \
            --regions $gangstr_reference_strs \
            --samp-sex M \
            --ref $reference_genome \
            --out $output_dir/$sample_id \
            --insertmean 1 \
            --insertsdev 1 \
            --minmatch 1 \
            --min-sample-reads 1

    cat output/gangstr_output/"${sample_id}".vcf | vcf-sort | bgzip -c > output/gangstr_output/"${sample_id}"_sorted.vcf.gz

done


#female samples
for sample_bam in $(cat $female_list); do

    sample_id=$(basename $sample_bam | cut -f1 -d".")

    GangSTR --bam $sample_bam \
            --bam-samps $sample_id \
            --regions $gangstr_reference_strs \
            --samp-sex F \
            --ref $reference_genome \
            --out $output_dir/$sample_id \
            --insertmean 1 \
            --insertsdev 1 \
            --minmatch 1 \
            --min-sample-reads 1

    cat output/gangstr_output/"${sample_id}".vcf | vcf-sort | bgzip -c > output/gangstr_output/"${sample_id}"_sorted.vcf.gz
            

done

mamba deactivate
# Out:
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG00108 for file 1000_genomes/HG00108.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 19	likelihood = 411.691
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 17	likelihood = 66.5938
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  31, 32	likelihood = 109.884
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 21	likelihood = 224.468
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.fqqbrR
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG00136 for file 1000_genomes/HG00136.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 23	likelihood = 406.558
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  15, 17	likelihood = 81.4652
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  27, 30	likelihood = 39.4583
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 10	likelihood = 163.306
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.WohcwW
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG00142 for file 1000_genomes/HG00142.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  20, 22	likelihood = 448.638
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 13	likelihood = 154.164
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  31, 32	likelihood = 74.1368
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  21, 43	likelihood = 266.881
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.zVvB5W
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG00155 for file 1000_genomes/HG00155.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  20, 20	likelihood = 385.91
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  12, 13	likelihood = 98.238
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  24, 31	likelihood = 73.3525
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 21	likelihood = 232.399
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.cvEa2y
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG00157 for file 1000_genomes/HG00157.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 20	likelihood = 230.004
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  12, 19	likelihood = 57.6933
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  29, 31	likelihood = 105.064
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  22, 30	likelihood = 187.396
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.uOPDpb
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG00242 for file 1000_genomes/HG00242.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 22	likelihood = 407.169
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 17	likelihood = 92.3841
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  27, 32	likelihood = 83.0447
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 22	likelihood = 316.438
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.RxEU1P
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG00260 for file 1000_genomes/HG00260.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  18, 30	likelihood = 332.949
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 17	likelihood = 72.5944
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  31, 31	likelihood = 73.5178
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 10	likelihood = 190.717
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.WZ6WsE
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG00284 for file 1000_genomes/HG00284.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 17	likelihood = 230.622
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 17	likelihood = 101.578
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  24, 31	likelihood = 63.3921
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 37	likelihood = 173.936
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.mC2p39
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG00336 for file 1000_genomes/HG00336.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  23, 24	likelihood = 322.501
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 17	likelihood = 76.0112
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  31, 31	likelihood = 113.926
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 10	likelihood = 174.444
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.BVw8Df
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG00472 for file 1000_genomes/HG00472.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  18, 32	likelihood = 309.699
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 13	likelihood = 71.0492
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  26, 31	likelihood = 83.0013
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 43	likelihood = 211.338
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.sTIOcj
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG00500 for file 1000_genomes/HG00500.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 17	likelihood = 378.62
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  12, 13	likelihood = 82.2895
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  26, 29	likelihood = 68.6344
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 18	likelihood = 261.734
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.Hzmf1b
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG00610 for file 1000_genomes/HG00610.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 20	likelihood = 230.222
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 14	likelihood = 98.5351
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  26, 30	likelihood = 84.4671
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  18, 40	likelihood = 217.107
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.5vnV0V
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG00640 for file 1000_genomes/HG00640.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  16, 21	likelihood = 343.013
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  12, 17	likelihood = 81.5858
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  31, 32	likelihood = 131.012
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 10	likelihood = 130.279
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.jIRtrx
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG00698 for file 1000_genomes/HG00698.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 20	likelihood = 350.446
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 17	likelihood = 85.9296
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  26, 27	likelihood = 105.395
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 39	likelihood = 314.267
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.6niTS9
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG00707 for file 1000_genomes/HG00707.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 20	likelihood = 370.574
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 13	likelihood = 86.8845
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  25, 29	likelihood = 116.538
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  21, 44	likelihood = 277.422
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.1Bf4e2
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG00739 for file 1000_genomes/HG00739.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 29	likelihood = 381.938
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  12, 15	likelihood = 41.677
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  31, 34	likelihood = 56.1288
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 10	likelihood = 151.78
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.74pMF5
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG01136 for file 1000_genomes/HG01136.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  18, 21	likelihood = 319.539
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 13	likelihood = 66.9435
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  32, 32	likelihood = 62.6923
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 10	likelihood = 163.694
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.FJg4Uf
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG01161 for file 1000_genomes/HG01161.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  20, 20	likelihood = 289.607
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 19	likelihood = 60.5146
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  28, 31	likelihood = 96.0619
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 22	likelihood = 180.933
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.jUBoSA
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG01200 for file 1000_genomes/HG01200.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 20	likelihood = 322.001
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 17	likelihood = 107.957
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  25, 27	likelihood = 97.1981
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 17	likelihood = 129.955
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.NbPWnP
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG01250 for file 1000_genomes/HG01250.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  18, 19	likelihood = 320.576
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 17	likelihood = 142.046
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  31, 32	likelihood = 70.2752
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  39, 39	likelihood = 249.808
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.lgXpZM
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG01271 for file 1000_genomes/HG01271.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  15, 23	likelihood = 267.447
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 14	likelihood = 103.088
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  30, 31	likelihood = 105.716
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  16, 17	likelihood = 191.304
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.u3gI00
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG01280 for file 1000_genomes/HG01280.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 24	likelihood = 357.298
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 13	likelihood = 55.1299
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  27, 28	likelihood = 77.68
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 17	likelihood = 179.828
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.6nQ6al
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG01325 for file 1000_genomes/HG01325.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 22	likelihood = 330.406
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 17	likelihood = 114.038
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  25, 31	likelihood = 55.2517
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  15, 21	likelihood = 168.586
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.d3zZua
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG01362 for file 1000_genomes/HG01362.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  19, 20	likelihood = 167.683
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 13	likelihood = 55.1299
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  25, 31	likelihood = 34.2119
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 21	likelihood = 203.945
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.LOMCcq
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG01374 for file 1000_genomes/HG01374.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 19	likelihood = 341.784
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 13	likelihood = 43.4842
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  30, 31	likelihood = 61.3833
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  22, 22	likelihood = 206.556
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.jBWpWz
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG01389 for file 1000_genomes/HG01389.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  18, 21	likelihood = 204.501
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 19	likelihood = 94.5819
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  30, 32	likelihood = 60.734
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  22, 26	likelihood = 221.953
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.PwJ6TE
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG01413 for file 1000_genomes/HG01413.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 20	likelihood = 277.918
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 13	likelihood = 98.782
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  31, 31	likelihood = 131.104
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  7, 16	likelihood = 204.44
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.xklpcn
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG01455 for file 1000_genomes/HG01455.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  15, 17	likelihood = 290.659
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 13	likelihood = 47.2542
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  31, 31	likelihood = 57.586
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  22, 44	likelihood = 226.323
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.aUHGjo
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG01464 for file 1000_genomes/HG01464.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 19	likelihood = 256.928
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 14	likelihood = 89.3689
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  31, 34	likelihood = 89.1371
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 43	likelihood = 223.836
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.CoSR1b
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG01678 for file 1000_genomes/HG01678.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 17	likelihood = 275.702
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  12, 13	likelihood = 68.6189
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  33, 33	likelihood = 77.4375
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 22	likelihood = 240.353
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.uG4u6l
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG01767 for file 1000_genomes/HG01767.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  18, 20	likelihood = 358.562
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  12, 12	likelihood = 145.793
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  29, 31	likelihood = 53.5679
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  18, 42	likelihood = 322.951
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.I5ogGo
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG01777 for file 1000_genomes/HG01777.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  15, 17	likelihood = 341.848
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 17	likelihood = 76.0112
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  32, 32	likelihood = 38.7936
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  21, 22	likelihood = 170.327
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.kUcyF3
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG01873 for file 1000_genomes/HG01873.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 19	likelihood = 245.747
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 13	likelihood = 78.7571
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  26, 29	likelihood = 105.235
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 44	likelihood = 263.77
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.PIl6Mm
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG01923 for file 1000_genomes/HG01923.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  20, 23	likelihood = 272.251
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  12, 13	likelihood = 94.9868
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  28, 32	likelihood = 78.3931
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  21, 40	likelihood = 205.467
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.WHW4SI
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG01982 for file 1000_genomes/HG01982.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  15, 20	likelihood = 263.642
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 13	likelihood = 47.2542
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  28, 31	likelihood = 64.3342
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  44, 44	likelihood = 227.175
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.m4B0VI
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG01991 for file 1000_genomes/HG01991.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  15, 15	likelihood = 164.624
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  18, 18	likelihood = 84.0674
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  34, 40	likelihood = 127.143
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 22	likelihood = 184.961
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.ved1ma
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG02008 for file 1000_genomes/HG02008.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 20	likelihood = 198.844
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 18	likelihood = 60.8037
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  29, 31	likelihood = 68.4929
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  21, 43	likelihood = 217.995
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.eYV54V
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG02017 for file 1000_genomes/HG02017.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 17	likelihood = 251.187
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  12, 13	likelihood = 100.601
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  30, 31	likelihood = 84.0989
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 21	likelihood = 84.8963
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.saYg9i
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG02023 for file 1000_genomes/HG02023.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 30	likelihood = 498.407
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 13	likelihood = 39.5464
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  26, 31	likelihood = 84.778
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 42	likelihood = 222.061
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.9W7kUj
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG02122 for file 1000_genomes/HG02122.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  12, 17	likelihood = 239.406
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 13	likelihood = 118.471
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  26, 32	likelihood = 89.922
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 24	likelihood = 270.556
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.642SvA
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG02143 for file 1000_genomes/HG02143.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  15, 18	likelihood = 339.199
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 19	likelihood = 151.762
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  32, 32	likelihood = 107.489
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  30, 30	likelihood = 389.398
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.lUnyg3
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG02236 for file 1000_genomes/HG02236.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  18, 22	likelihood = 313.227
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 13	likelihood = 82.6949
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  29, 31	likelihood = 81.3441
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 21	likelihood = 148.931
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.AyX9vS
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG02238 for file 1000_genomes/HG02238.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 17	likelihood = 175.535
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 13	likelihood = 94.8442
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  29, 31	likelihood = 72.0875
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 17	likelihood = 234.518
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.wZlTWI
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG02277 for file 1000_genomes/HG02277.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  15, 20	likelihood = 377.24
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 13	likelihood = 70.8814
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  30, 32	likelihood = 115.442
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  42, 42	likelihood = 257.43
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.5UleGj
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG02343 for file 1000_genomes/HG02343.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  18, 19	likelihood = 243.251
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 13	likelihood = 70.8814
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  27, 34	likelihood = 105.805
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  22, 25	likelihood = 221.291
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.whXxH4
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG02364 for file 1000_genomes/HG02364.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  15, 18	likelihood = 387.196
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 14	likelihood = 105.636
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  26, 31	likelihood = 90.1403
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 40	likelihood = 283.177
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.Eq31pl
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG02375 for file 1000_genomes/HG02375.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 20	likelihood = 357.157
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 23	likelihood = 72.5826
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  31, 31	likelihood = 120.675
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 10	likelihood = 191.105
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.kH9XQr
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG02380 for file 1000_genomes/HG02380.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 17	likelihood = 297.315
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 13	likelihood = 82.8628
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  26, 30	likelihood = 95.699
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  39, 39	likelihood = 234.668
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.4p5BA3
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG02390 for file 1000_genomes/HG02390.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  16, 18	likelihood = 211.973
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 13	likelihood = 82.6949
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  25, 26	likelihood = 120.324
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 39	likelihood = 197.607
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.FAkHMn
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  HG02394 for file 1000_genomes/HG02394.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  16, 19	likelihood = 356.612
# ...
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  27, 31	likelihood = 68.9267
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 17	likelihood = 164.162
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.ES50pf
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  NA19355 for file 1000_genomes/NA19355.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  15, 18	likelihood = 276.432
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  14, 15	likelihood = 117.266
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  31, 31	likelihood = 49.6201
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 34	likelihood = 179.769
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.rJ9Njf
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  NA19663 for file 1000_genomes/NA19663.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 17	likelihood = 169.882
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 18	likelihood = 90.3602
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  28, 32	likelihood = 101.189
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 22	likelihood = 193.96
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.Ye7odD
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  NA19669 for file 1000_genomes/NA19669.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  15, 18	likelihood = 136.671
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 17	likelihood = 60.4747
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  31, 31	likelihood = 82.7001
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 43	likelihood = 266.61
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.IGnXXP
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  NA19678 for file 1000_genomes/NA19678.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 19	likelihood = 380.639
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 13	likelihood = 134.391
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  27, 32	likelihood = 107.164
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  43, 43	likelihood = 227.16
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.e7nnJe
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  NA19740 for file 1000_genomes/NA19740.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  15, 20	likelihood = 381.733
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  18, 19	likelihood = 56.1419
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  27, 32	likelihood = 29.5743
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 21	likelihood = 183.417
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.MfKv1h
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  NA19770 for file 1000_genomes/NA19770.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  15, 19	likelihood = 365.159
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 19	likelihood = 37.3596
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  31, 31	likelihood = 67.3766
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  22, 44	likelihood = 246.876
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.RZ3Nhz
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  NA19785 for file 1000_genomes/NA19785.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  15, 18	likelihood = 216.418
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  12, 13	likelihood = 146.139
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  27, 31	likelihood = 108.929
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 16	likelihood = 192.88
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.tsF9Mm
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  NA19794 for file 1000_genomes/NA19794.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  15, 19	likelihood = 411.094
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  12, 13	likelihood = 100.542
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  25, 31	likelihood = 63.4436
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 39	likelihood = 224.864
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.J8VRiK
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  NA20287 for file 1000_genomes/NA20287.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  19, 19	likelihood = 491.592
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  12, 16	likelihood = 137.802
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  29, 31	likelihood = 149.315
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  16, 19	likelihood = 353.808
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.rlt44t
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  NA20296 for file 1000_genomes/NA20296.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  19, 23	likelihood = 260.119
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  14, 15	likelihood = 55.2421
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  31, 31	likelihood = 60.0189
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 26	likelihood = 134.352
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.XgW68d
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  NA20332 for file 1000_genomes/NA20332.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 23	likelihood = 270.732
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 15	likelihood = 88.0633
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  27, 31	likelihood = 118.978
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 10	likelihood = 167.277
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.YJZj87
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  NA20357 for file 1000_genomes/NA20357.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  19, 27	likelihood = 396.368
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 13	likelihood = 90.9902
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  26, 29	likelihood = 109.172
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 26	likelihood = 223.428
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.r5urpY
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  NA20522 for file 1000_genomes/NA20522.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  24, 26	likelihood = 415.234
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 18	likelihood = 61.1254
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  26, 27	likelihood = 69.0398
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  26, 44	likelihood = 259.649
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.7ZbWp8
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  NA20760 for file 1000_genomes/NA20760.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  19, 20	likelihood = 220.203
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  12, 13	likelihood = 129.149
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  27, 31	likelihood = 55.4181
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  21, 22	likelihood = 167.934
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.SEnli0
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  NA20910 for file 1000_genomes/NA20910.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 22	likelihood = 324.159
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  12, 13	likelihood = 105.167
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  26, 32	likelihood = 86.2363
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  10, 17	likelihood = 206.132
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.f8doiZ
# Merging 1 temporary files
# Cleaning
# Done
# [GangSTR-2.5.0] ProgressMeter: Loading read group  NA21088 for file 1000_genomes/NA21088.bam
# [GangSTR-2.5.0] ProgressMeter: Processing chr1:77887913
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# [GangSTR-2.5.0] ProgressMeter: Processing chr4:3074877
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  14, 24	likelihood = 446.083
# [GangSTR-2.5.0] ProgressMeter: Processing chr11:57528484
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  13, 17	likelihood = 93.7538
# [GangSTR-2.5.0] ProgressMeter: Processing chr14:64253561
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  30, 31	likelihood = 135.663
# [GangSTR-2.5.0] ProgressMeter: Processing chr17:51831668
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  17, 18	likelihood = 207.326
# [GangSTR-2.5.0] ProgressMeter: Processing chr21:43776443
# [GangSTR-2.5.0] ProgressMeter: 	Genotyper Results:  1, 1	likelihood = -25
# Writing to /tmp/bcftools.af8bMO
# Merging 1 temporary files
# Cleaning
# Done

# %%
# merging sample VCFs to population VCF
populations=("africa" "europe" "east_asia" "south_asia" "america")

for population in "${populations[@]}"; do
        
    sample_vcfs=$(ls -1 output/gangstr_output/*_sorted.vcf.gz | \
    grep -f str_resources/"${population}"_ids.csv | tr "\n" "," | sed 's/,$//')
    
    mergeSTR \
        --vcfs $sample_vcfs \
        --vcftype 'gangstr' \
        --out output/gangstr_output/"${population}"_gangstr
        
        
    cat output/gangstr_output/"${population}"_gangstr.vcf | vcf-sort | bgzip -c > output/gangstr_output/"${population}"_gangstr.vcf.gz
    tabix -p vcf output/gangstr_output/"${population}"_gangstr.vcf.gz
    
done

# %% [markdown]
# ## adVNTR

# %%
# view VNTR ID of CSTB gene

mamba activate advntr

advntr viewmodel --gene CSTB --pattern GCGCGGGGCGGG --models str_resources/vntr_data/hg19_selected_VNTRs_Illumina.db
# Out:
# Using Theano backend.
# VNTR ID	| Chr	| Gene	| Start Position | Pattern
# --------------------------------------------------
# 301645	| chr21	|CSTB	| 45196323	 | GCGCGGGGCGGG

# %%
advntr_model=str_resources/vntr_data/hg19_selected_VNTRs_Illumina.db
output_dir=output/advntr_output
advntr_dir=output/advntr_output/advntr_dir
bam_list=str_resources/bam_list.txt


# main script
for sample_bam in $(cat $bam_list); do

    sample_id=$(basename $sample_bam | cut -f1 -d".")

    advntr genotype \
            --vntr_id 301645 \
            --alignment_file $sample_bam \
            --outfmt vcf \
            --outfile $output_dir/"${sample_id}".vcf \
            --models $advntr_model \
            --working_directory $advntr_dir
    
    cat $output_dir/"${sample_id}".vcf | vcf-sort | bgzip -c > $output_dir/"${sample_id}"_sorted.vcf.gz
    tabix -p vcf output/advntr_output/"${sample_id}".vcf.gz


done

mamba deactivate
# Out:
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 284 reads
# Writing to /tmp/bcftools.JGxEcL
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 278 reads
# Writing to /tmp/bcftools.2OHy3d
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 281 reads
# Writing to /tmp/bcftools.7L7phe
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 206 reads
# Writing to /tmp/bcftools.yX4jRp
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 233 reads
# Writing to /tmp/bcftools.kLBGfi
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 207 reads
# Writing to /tmp/bcftools.EB0bcL
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 253 reads
# Writing to /tmp/bcftools.LmSVju
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 345 reads
# Writing to /tmp/bcftools.pHBADS
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 281 reads
# Writing to /tmp/bcftools.zUa8z5
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 426 reads
# Writing to /tmp/bcftools.Jy57Ds
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 198 reads
# Writing to /tmp/bcftools.RhFVxT
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 224 reads
# Writing to /tmp/bcftools.VM6iHl
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 221 reads
# Writing to /tmp/bcftools.c8gHfN
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 259 reads
# Writing to /tmp/bcftools.m5t7VD
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 225 reads
# Writing to /tmp/bcftools.qgf8BW
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 207 reads
# Writing to /tmp/bcftools.foWOaX
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 307 reads
# Writing to /tmp/bcftools.rQTkuA
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 270 reads
# Writing to /tmp/bcftools.yt5UWl
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 325 reads
# Writing to /tmp/bcftools.inRZ8S
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 262 reads
# Writing to /tmp/bcftools.RAhddj
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 277 reads
# Writing to /tmp/bcftools.cYKj6j
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 265 reads
# Writing to /tmp/bcftools.JwiAvE
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 291 reads
# Writing to /tmp/bcftools.Yct01I
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 278 reads
# Writing to /tmp/bcftools.ej7u9R
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 361 reads
# Writing to /tmp/bcftools.Pcd52s
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 355 reads
# Writing to /tmp/bcftools.r3Qgps
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 174 reads
# Writing to /tmp/bcftools.Bn2kJN
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 251 reads
# Writing to /tmp/bcftools.AK3IsQ
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 262 reads
# Writing to /tmp/bcftools.Y3j46C
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 213 reads
# Writing to /tmp/bcftools.Sfa9ih
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 190 reads
# Writing to /tmp/bcftools.xWZuyK
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 321 reads
# Writing to /tmp/bcftools.YvWAYC
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 282 reads
# Writing to /tmp/bcftools.DD00Gi
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 206 reads
# Writing to /tmp/bcftools.w5FsnP
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 384 reads
# Writing to /tmp/bcftools.YyAniz
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 258 reads
# Writing to /tmp/bcftools.EwJvqC
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 232 reads
# Writing to /tmp/bcftools.Sml8sE
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 229 reads
# Writing to /tmp/bcftools.hf8lmD
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 246 reads
# Writing to /tmp/bcftools.yW8uEm
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 326 reads
# Writing to /tmp/bcftools.tON5kr
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 197 reads
# Writing to /tmp/bcftools.yCBsQ9
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 249 reads
# Writing to /tmp/bcftools.yYmPo5
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 227 reads
# Writing to /tmp/bcftools.zcCUJH
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 297 reads
# Writing to /tmp/bcftools.pvLZwP
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 316 reads
# Writing to /tmp/bcftools.MosCjt
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 281 reads
# Writing to /tmp/bcftools.q6kojO
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 224 reads
# Writing to /tmp/bcftools.HnGD4Z
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 204 reads
# Writing to /tmp/bcftools.zKOaZY
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 237 reads
# Writing to /tmp/bcftools.T2w4Gc
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 218 reads
# Writing to /tmp/bcftools.QNqP0H
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 273 reads
# Writing to /tmp/bcftools.t0OMmT
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 219 reads
# Writing to /tmp/bcftools.PrJOjD
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 193 reads
# Writing to /tmp/bcftools.d1Sgxr
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 267 reads
# Writing to /tmp/bcftools.PdAajL
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 480 reads
# Writing to /tmp/bcftools.0DM1en
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 256 reads
# Writing to /tmp/bcftools.SgIySs
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 247 reads
# Writing to /tmp/bcftools.1yRuQp
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 188 reads
# Writing to /tmp/bcftools.b5t0ar
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 269 reads
# Writing to /tmp/bcftools.dUhqDN
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 265 reads
# Writing to /tmp/bcftools.4qd7Pd
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 235 reads
# Writing to /tmp/bcftools.IZ33KS
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 218 reads
# Writing to /tmp/bcftools.SoUbbe
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 150 reads
# Writing to /tmp/bcftools.jmMhRo
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 190 reads
# Writing to /tmp/bcftools.NKjlGl
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 244 reads
# Writing to /tmp/bcftools.Zrmiq2
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 216 reads
# Writing to /tmp/bcftools.8PjRia
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 220 reads
# Writing to /tmp/bcftools.Sc69Gc
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 210 reads
# Writing to /tmp/bcftools.mKYJnO
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 267 reads
# Writing to /tmp/bcftools.arzEzS
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 263 reads
# Writing to /tmp/bcftools.y1z7dV
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 244 reads
# Writing to /tmp/bcftools.nsPOSm
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 309 reads
# Writing to /tmp/bcftools.1wPqnN
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 260 reads
# Writing to /tmp/bcftools.Is0Cf7
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 233 reads
# Writing to /tmp/bcftools.wyZjXB
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 208 reads
# Writing to /tmp/bcftools.WiC69p
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 273 reads
# Writing to /tmp/bcftools.TX9SgF
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 182 reads
# Writing to /tmp/bcftools.V377FM
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 255 reads
# Writing to /tmp/bcftools.6Gv8ld
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 209 reads
# Writing to /tmp/bcftools.yLA8Wq
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 180 reads
# Writing to /tmp/bcftools.PeIdv4
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 244 reads
# Writing to /tmp/bcftools.znivK4
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 227 reads
# Writing to /tmp/bcftools.54RteC
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 268 reads
# Writing to /tmp/bcftools.lWp8Fu
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 233 reads
# Writing to /tmp/bcftools.4EdDJi
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 261 reads
# Writing to /tmp/bcftools.DE6FBF
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 285 reads
# Writing to /tmp/bcftools.MGbQT0
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 229 reads
# Writing to /tmp/bcftools.adc3pH
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 228 reads
# Writing to /tmp/bcftools.cO8uKY
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 234 reads
# Writing to /tmp/bcftools.7uhirW
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 262 reads
# Writing to /tmp/bcftools.g6VOuQ
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 228 reads
# Writing to /tmp/bcftools.lqMJVn
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 216 reads
# Writing to /tmp/bcftools.WdM0vn
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 267 reads
# Writing to /tmp/bcftools.JdbyMb
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 221 reads
# Writing to /tmp/bcftools.xqV9zj
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 278 reads
# Writing to /tmp/bcftools.lnioYT
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 253 reads
# Writing to /tmp/bcftools.BPi7xl
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 270 reads
# Writing to /tmp/bcftools.oQEW2V
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 188 reads
# Writing to /tmp/bcftools.V8WLJE
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 222 reads
# Writing to /tmp/bcftools.oOTBCl
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 216 reads
# Writing to /tmp/bcftools.Jytk1w
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 264 reads
# Writing to /tmp/bcftools.1WQvei
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 248 reads
# Writing to /tmp/bcftools.6rVB84
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 307 reads
# Writing to /tmp/bcftools.ztNHOi
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 220 reads
# Writing to /tmp/bcftools.ldHjvK
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 210 reads
# Writing to /tmp/bcftools.eYuyn8
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 242 reads
# Writing to /tmp/bcftools.kE7Q8t
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 241 reads
# Writing to /tmp/bcftools.BRcJYS
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 271 reads
# Writing to /tmp/bcftools.O0Q2Jq
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 273 reads
# Writing to /tmp/bcftools.SYs2lG
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 265 reads
# Writing to /tmp/bcftools.tZrNS0
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 205 reads
# Writing to /tmp/bcftools.oJr2DN
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 190 reads
# Writing to /tmp/bcftools.BNnyQc
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 162 reads
# Writing to /tmp/bcftools.YRsHaZ
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 235 reads
# Writing to /tmp/bcftools.cAOj52
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 242 reads
# Writing to /tmp/bcftools.tPG8FV
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 318 reads
# Writing to /tmp/bcftools.OODWYc
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 262 reads
# Writing to /tmp/bcftools.wfkrxP
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 223 reads
# Writing to /tmp/bcftools.U8z8gy
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 243 reads
# Writing to /tmp/bcftools.prnRfl
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 264 reads
# Writing to /tmp/bcftools.wHgw1U
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 215 reads
# Writing to /tmp/bcftools.xWpzRs
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 221 reads
# Writing to /tmp/bcftools.GIg7a2
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 258 reads
# Writing to /tmp/bcftools.B4XALC
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 202 reads
# Writing to /tmp/bcftools.EAKDvE
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 211 reads
# Writing to /tmp/bcftools.0HrpNe
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 352 reads
# Writing to /tmp/bcftools.4bdyIz
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 204 reads
# Writing to /tmp/bcftools.Z3jPmt
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 292 reads
# Writing to /tmp/bcftools.G5Mpyi
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 221 reads
# Writing to /tmp/bcftools.ENyDgX
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 316 reads
# Writing to /tmp/bcftools.DH1EIn
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 268 reads
# Writing to /tmp/bcftools.KyJfaN
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 267 reads
# Writing to /tmp/bcftools.n4qdxt
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 240 reads
# Writing to /tmp/bcftools.iI451L
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 283 reads
# Writing to /tmp/bcftools.jsGU9F
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 251 reads
# Writing to /tmp/bcftools.2RM7Iq
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 238 reads
# Writing to /tmp/bcftools.cXakNU
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 245 reads
# Writing to /tmp/bcftools.wlMptR
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 250 reads
# Writing to /tmp/bcftools.okG5cv
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 291 reads
# Writing to /tmp/bcftools.yVtFmD
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 231 reads
# Writing to /tmp/bcftools.QT13vm
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 271 reads
# Writing to /tmp/bcftools.evoluj
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 224 reads
# Writing to /tmp/bcftools.SDXaq2
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 321 reads
# Writing to /tmp/bcftools.nc1Iao
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 330 reads
# Writing to /tmp/bcftools.hvnAUx
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 270 reads
# Writing to /tmp/bcftools.UDHkxk
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 256 reads
# Writing to /tmp/bcftools.ICBtRe
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 344 reads
# Writing to /tmp/bcftools.od2KLP
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 294 reads
# Writing to /tmp/bcftools.ivbkDu
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 238 reads
# Writing to /tmp/bcftools.1WCEuu
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 236 reads
# Writing to /tmp/bcftools.4cX9OI
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 255 reads
# Writing to /tmp/bcftools.0M7oxR
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 246 reads
# Writing to /tmp/bcftools.dhLGXE
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 264 reads
# Writing to /tmp/bcftools.80Ki9p
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 259 reads
# Writing to /tmp/bcftools.3JJdaC
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 246 reads
# Writing to /tmp/bcftools.BuXzkY
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 2113 reads
# Writing to /tmp/bcftools.fKxjFA
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 329 reads
# Writing to /tmp/bcftools.FM9bnf
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 224 reads
# Writing to /tmp/bcftools.PAcSGF
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 290 reads
# Writing to /tmp/bcftools.PmqcQP
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 268 reads
# Writing to /tmp/bcftools.BTnqsm
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 424 reads
# Writing to /tmp/bcftools.SOU4SF
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 306 reads
# Writing to /tmp/bcftools.858MdS
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 235 reads
# Writing to /tmp/bcftools.NA15GN
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 345 reads
# Writing to /tmp/bcftools.ck417a
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 330 reads
# Writing to /tmp/bcftools.yGo5xo
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 231 reads
# Writing to /tmp/bcftools.J7HPg4
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 353 reads
# Writing to /tmp/bcftools.c8uDSY
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 343 reads
# Writing to /tmp/bcftools.MFtJKe
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 451 reads
# Writing to /tmp/bcftools.LTSXs0
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 458 reads
# Writing to /tmp/bcftools.06Pzw1
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 382 reads
# Writing to /tmp/bcftools.2F6fMk
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 354 reads
# Writing to /tmp/bcftools.jswTWL
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 310 reads
# Writing to /tmp/bcftools.TP67j7
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 330 reads
# Writing to /tmp/bcftools.RGvjP9
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 239 reads
# Writing to /tmp/bcftools.aIZh0u
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 318 reads
# Writing to /tmp/bcftools.lFpLS7
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 329 reads
# Writing to /tmp/bcftools.6LIR6l
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 166 reads
# Writing to /tmp/bcftools.rqhIXJ
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 201 reads
# Writing to /tmp/bcftools.n9kDjW
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 323 reads
# Writing to /tmp/bcftools.9n1uWd
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 288 reads
# Writing to /tmp/bcftools.oYX2lc
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 301 reads
# Writing to /tmp/bcftools.qj8lms
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 260 reads
# Writing to /tmp/bcftools.zj8jr6
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 266 reads
# Writing to /tmp/bcftools.mR83E6
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 276 reads
# Writing to /tmp/bcftools.yzihzU
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 233 reads
# Writing to /tmp/bcftools.vlC9C7
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 213 reads
# Writing to /tmp/bcftools.6NA7Hf
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 238 reads
# Writing to /tmp/bcftools.BhcrCJ
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 303 reads
# Writing to /tmp/bcftools.rknJZ7
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 305 reads
# Writing to /tmp/bcftools.NdHH6O
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 259 reads
# Writing to /tmp/bcftools.Yv7jjq
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 225 reads
# Writing to /tmp/bcftools.R9DtWE
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 324 reads
# Writing to /tmp/bcftools.iBDzNw
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 427 reads
# Writing to /tmp/bcftools.9LhGWH
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 211 reads
# Writing to /tmp/bcftools.xpS7iU
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 432 reads
# Writing to /tmp/bcftools.OIQKTB
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 237 reads
# Writing to /tmp/bcftools.0rJx5b
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 217 reads
# Writing to /tmp/bcftools.zMhFkv
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 269 reads
# Writing to /tmp/bcftools.OFU7Ti
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 248 reads
# Writing to /tmp/bcftools.svwoBu
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 293 reads
# Writing to /tmp/bcftools.i5OboR
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 246 reads
# Writing to /tmp/bcftools.itfMoc
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 299 reads
# Writing to /tmp/bcftools.5PNDkj
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 220 reads
# Writing to /tmp/bcftools.sv8NSr
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 243 reads
# Writing to /tmp/bcftools.XBhq0i
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 209 reads
# Writing to /tmp/bcftools.R6ANZf
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 301 reads
# Writing to /tmp/bcftools.sIjYe5
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 266 reads
# Writing to /tmp/bcftools.A6GMvq
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 253 reads
# Writing to /tmp/bcftools.NSA3gk
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 183 reads
# Writing to /tmp/bcftools.XPWllP
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 243 reads
# Writing to /tmp/bcftools.visU5T
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 247 reads
# Writing to /tmp/bcftools.MGUXJh
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 261 reads
# Writing to /tmp/bcftools.lZthBC
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 238 reads
# Writing to /tmp/bcftools.HLFYGx
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 175 reads
# Writing to /tmp/bcftools.gMMa9Z
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 223 reads
# Writing to /tmp/bcftools.v9ge6M
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 190 reads
# Writing to /tmp/bcftools.xbR9lc
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 174 reads
# Writing to /tmp/bcftools.jUDBwe
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 226 reads
# Writing to /tmp/bcftools.dPWQy8
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 231 reads
# Writing to /tmp/bcftools.QCteUX
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 278 reads
# Writing to /tmp/bcftools.zXms3s
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 245 reads
# Writing to /tmp/bcftools.lepRBI
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 233 reads
# Writing to /tmp/bcftools.jebUc0
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 218 reads
# Writing to /tmp/bcftools.zH5SY4
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 224 reads
# Writing to /tmp/bcftools.UjG45F
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 255 reads
# Writing to /tmp/bcftools.HSbkKC
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 303 reads
# Writing to /tmp/bcftools.TfUhsQ
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 170 reads
# Writing to /tmp/bcftools.TOsukm
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 265 reads
# Writing to /tmp/bcftools.v3FzPt
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 349 reads
# Writing to /tmp/bcftools.OYdPz4
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 225 reads
# Writing to /tmp/bcftools.QCfiXR
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 215 reads
# Writing to /tmp/bcftools.qWkLMW
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 347 reads
# Writing to /tmp/bcftools.ppRf0d
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 288 reads
# Writing to /tmp/bcftools.AwVkqb
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 388 reads
# Writing to /tmp/bcftools.Zw987s
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 249 reads
# Writing to /tmp/bcftools.OBjNDP
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 244 reads
# Writing to /tmp/bcftools.6NOlIQ
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 228 reads
# Writing to /tmp/bcftools.lraS9j
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 287 reads
# Writing to /tmp/bcftools.2jXmRM
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 322 reads
# Writing to /tmp/bcftools.f86UtX
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 372 reads
# Writing to /tmp/bcftools.VU2BoO
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 236 reads
# Writing to /tmp/bcftools.Ig0z1W
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 313 reads
# Writing to /tmp/bcftools.g9kiCV
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 329 reads
# Writing to /tmp/bcftools.jg4Gev
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 300 reads
# Writing to /tmp/bcftools.cG2Tn7
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 260 reads
# Writing to /tmp/bcftools.S89roa
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 304 reads
# Writing to /tmp/bcftools.AwAo3b
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 243 reads
# Writing to /tmp/bcftools.415Q6w
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 417 reads
# Writing to /tmp/bcftools.WXjg3J
# Merging 1 temporary files
# Cleaning
# Done
# Using Theano backend.
# [M::bam2fq_mainloop] discarded 0 singletons
# [M::bam2fq_mainloop] processed 350 reads
# Writing to /tmp/bcftools.fhVeo4
# Merging 1 temporary files
# Cleaning
# Done

# %%
populations=("africa" "europe" "east_asia" "south_asia" "america")

for population in "${populations[@]}"; do
        
    # comma-seperated list of vcfs
    sample_vcfs=$(ls -1 output/advntr_output/*_sorted.vcf.gz | \
    grep -f str_resources/"${population}"_ids.csv | tr "\n" "," | sed 's/,$//')
    
    mergeSTR \
        --vcfs $sample_vcfs \
        --vcftype 'advntr' \
        --out output/advntr_output/"${population}"_advntr

    cat output/advntr_output/"${population}"_advntr.vcf | vcf-sort | bgzip -c > output/advntr_output/"${population}"_advntr.vcf.gz
    tabix -p vcf output/advntr_output/"${population}"_advntr.vcf.gz


done
# Out:
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n

# %% [markdown]
# ## Merging population VCFs from each tools

# %%
# gangstr
mergeSTR \
    --vcfs output/gangstr_output/africa_gangstr.vcf.gz,output/gangstr_output/east_asia_gangstr.vcf.gz,output/gangstr_output/south_asia_gangstr.vcf.gz,output/gangstr_output/america_gangstr.vcf.gz,output/gangstr_output/europe_gangstr.vcf.gz \
    --vcftype 'gangstr' \
    --out output/ensembletr_output/gangstr_strs

cat output/ensembletr_output/gangstr_strs.vcf | vcf-sort | bgzip -c > output/ensembletr_output/gangstr_strs.vcf.gz
tabix -p vcf output/ensembletr_output/gangstr_strs.vcf.gz

# expansionhunter
mergeSTR \
    --vcfs output/eh_output/africa_eh.vcf.gz,output/eh_output/east_asia_eh.vcf.gz,output/eh_output/south_asia_eh.vcf.gz,output/eh_output/america_eh.vcf.gz,output/eh_output/europe_eh.vcf.gz \
    --vcftype 'eh' \
    --out output/ensembletr_output/eh_strs

cat output/ensembletr_output/eh_strs.vcf | vcf-sort | bgzip -c > output/ensembletr_output/eh_strs.vcf.gz
tabix -p vcf output/ensembletr_output/eh_strs.vcf.gz

#advntr
mergeSTR \
    --vcfs output/advntr_output/africa_advntr.vcf.gz,output/advntr_output/east_asia_advntr.vcf.gz,output/advntr_output/south_asia_advntr.vcf.gz,output/advntr_output/america_advntr.vcf.gz,output/advntr_output/europe_advntr.vcf.gz \
    --vcftype 'advntr' \
    --out output/ensembletr_output/advntr_strs 
        
cat output/ensembletr_output/advntr_strs.vcf | vcf-sort | bgzip -c > output/ensembletr_output/advntr_strs.vcf.gz
tabix -p vcf output/ensembletr_output/advntr_strs.vcf.gz

# hipstr
mergeSTR \
    --vcfs output/hipstr_output/africa_hipstr_sorted.vcf.gz,output/hipstr_output/east_asia_hipstr_sorted.vcf.gz,output/hipstr_output/south_asia_hipstr_sorted.vcf.gz,output/hipstr_output/america_hipstr_sorted.vcf.gz,output/hipstr_output/europe_hipstr_sorted.vcf.gz \
    --vcftype 'hipstr' \
    --out output/ensembletr_output/hipstr_strs

cat output/ensembletr_output/hipstr_strs.vcf | vcf-sort | bgzip -c > output/ensembletr_output/hipstr_strs.vcf.gz
tabix -p vcf output/ensembletr_output/hipstr_strs.vcf.gz
# Out:
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n

# %% [markdown]
# ## EnsembleTR consensus genotyping

# %%
reference_genome="references/reference_chroms.fa"

EnsembleTR \
    --ref $reference_genome \
    --vcfs output/ensembletr_output/advntr_strs.vcf.gz,output/ensembletr_output/eh_strs.vcf.gz,output/ensembletr_output/gangstr_strs.vcf.gz,output/ensembletr_output/hipstr_strs.vcf.gz \
    --out output/ensembletr_output/ensembletr.vcf
    
cat output/ensembletr_output/ensembletr.vcf | vcf-sort | bgzip -c > output/ensembletr_output/ensembletr.vcf.gz
tabix -p vcf output/ensembletr_output/ensembletr.vcf.gz
# Out:
# [W::vcf_parse_format_fill5] Extreme FORMAT/DAB value encountered and set to missing at chr4:3074877
# Analysing record cluster ranged in chr21:45196324-45196359.
# Analysing record cluster ranged in chr1:77887914-77888010.
# Analysing record cluster ranged in chr1:77887913-77888010.
# Analysing record cluster ranged in chr4:3074878-3074933.
# Analysing record cluster ranged in chr4:3074877-3074933.
# Analysing record cluster ranged in chr4:3074877-3074968.
# Analysing record cluster ranged in chr4:3074940-3074966.
# Analysing record cluster ranged in chr11:57528485-57528517.
# Analysing record cluster ranged in chr11:57528484-57528517.
# Analysing record cluster ranged in chr11:57528484-57528517.
# Analysing record cluster ranged in chr14:64253562-64253619.
# Analysing record cluster ranged in chr14:64253561-64253619.
# Analysing record cluster ranged in chr14:64253561-64253619.
# Analysing record cluster ranged in chr17:51831669-51831730.
# Analysing record cluster ranged in chr17:51831668-51831730.
# Analysing record cluster ranged in chr17:51831668-51831732.
# Analysing record cluster ranged in chr21:43776444-43776479.
# Analysing record cluster ranged in chr21:43776443-43776479.
# sort -k1,1d -k2,2n
